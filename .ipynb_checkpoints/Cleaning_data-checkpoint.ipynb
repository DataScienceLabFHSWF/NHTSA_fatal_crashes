# %%
import pandas as pd
from os import listdir

# %%
directory = listdir("./Data/National/2000/")
frame_dict = {}

# %%
directory
# Out:
# ['ACCIDENT.CSV',
#  'MIACC.CSV',
#  'MIDRVACC.CSV',
#  'MIPER.CSV',
#  'PERSON.CSV',
#  'VEHICLE.CSV']

# %%
subdirectory = 'National'
year = '2000'
for i in directory:
    frame_dict[i[:-4]] = pd.read_csv('./Data/'+subdirectory+'/'+year+'/'+i)
# Out:
# C:\Users\Ferdi\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (53) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
directory[1][:-4]
# Out:
# 'MIACC'

# %%
pd.read_csv('./Data/'+subdirectory+'/'+year+'/'+'ACCIDENT.CSV')
# Out:
#        STATE  COUNTY  MONTH  DAY  HOUR  MINUTE  VE_FORMS  PERSONS  PEDS  NHS  \
# 0          1     117      1    1     5      24         1        5     1    0
# 1          1       1      1    3    18      35         1        1     0    0
# 2          1      73      1    9     8      45         1        1     0    0
# 3          1      21      1    6     3      25         1        1     0    0
# 4          1      53      1    4     9      35         3        3     0    1
# ...      ...     ...    ...  ...   ...     ...       ...      ...   ...  ...
# 37521     56       1     12   18    12      30         2        1     0    1
# 37522     56      27     12   28    11      45         2       11     0    1
# 37523     56      37     12   24    13      19         1       10     0    1
# 37524     56      21     12   30    15      45         2        3     0    1
# 37525     56      13     12   20    21       7         1        3     1    0
#
# ...
